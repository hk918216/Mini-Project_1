# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 경기도

# %%
ggd_ingu = pd.read_csv('./미니1차/경기도인구군3개추가.csv', encoding='euc-kr')

# %%
# ggd_ingu = ggd_ingu.drop(0, axis=0)

# %%
ggd_ingu.loc[27,['2010','2011','2012']]=0

# %%
ggd_si = ggd_ingu[['행정구역(시군구)별','2019']]
ggd_si['2019']=ggd_si['2019'].astype(int)
ggd_si.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   행정구역(시군구)별  31 non-null     object
#  1   2019        31 non-null     int32
# dtypes: int32(1), object(1)
# memory usage: 500.0+ bytes
# C:\Users\admin\AppData\Local\Temp\ipykernel_14320\3409760017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ggd_si['2019']=ggd_si['2019'].astype(int)

# %%
ggd_si
# Out:
#    행정구역(시군구)별    2019
# 0         수원시  498836
# 1         성남시  400460
# 2        의정부시  190760
# 3         안양시  222589
# 4         부천시  340160
# 5         광명시  126001
# 6         평택시  226020
# 7        동두천시   42999
# 8         안산시  277331
# 9         고양시  434028
# 10        과천시   21467
# 11        구리시   79870
# 12       남양주시  276656
# 13        오산시   95209
# 14        시흥시  194750
# 15        군포시  110005
# 16        의왕시   62387
# 17        하남시  115792
# 18        용인시  406880
# 19        파주시  191668
# 20        이천시   92643
# 21        안성시   81599
# 22        김포시  174613
# 23        화성시  327797
# 24        광주시  156884
# 25        양주시   93026
# 26        포천시   69976
# 27        여주시   50334
# 28        연천군   21630
# 29        가평군   30768
# 30        양평군   55782

# %%
age_ggd = pd.read_csv('./미니1차/경기도연령대비율_2019.csv', encoding='euc-kr')

# %%
age_ggd= age_ggd.drop(0, axis=0)

# %%
age_ggd = age_ggd.reset_index(drop=True)

# %%
age_ggd = age_ggd.rename(columns={'구분별(2)':'시군명'})
#age_ggd[['15-19세','20-29세','30-39세','40-49세','50-59세','60세이상']]= age_ggd[['15-19세','20-29세','30-39세','40-49세','50-59세','60세이상']].astype(int)

# %%
age_ggd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군명     31 non-null     object
#  1   15-19세  31 non-null     float64
#  2   20-29세  31 non-null     float64
#  3   30-39세  31 non-null     float64
#  4   40-49세  31 non-null     float64
#  5   50-59세  31 non-null     float64
#  6   60세이상   31 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.8+ KB

# %%
age_ggd
# Out:
#      시군명  15-19세  20-29세  30-39세  40-49세  50-59세  60세이상
# 0    수원시     6.9    17.8    18.1    20.0    19.0   18.2
# 1    성남시     6.9    15.2    17.0    19.4    18.9   22.6
# 2   의정부시     6.4    15.6    15.2    18.9    19.9   24.0
# 3    안양시     8.0    14.7    16.3    18.5    20.4   22.1
# 4    부천시     6.3    15.7    16.7    18.2    20.7   22.3
# 5    광명시     6.9    14.5    16.7    20.1    19.1   22.7
# 6    평택시     7.8    14.4    17.5    20.5    19.0   20.8
# 7   동두천시     5.6    13.6    13.0    18.0    19.6   30.3
# 8    안산시     7.1    18.2    15.1    19.6    21.9   18.2
# 9    고양시     8.4    14.2    15.2    20.1    20.5   21.6
# 10   과천시     7.7    15.1    15.1    18.2    20.4   23.5
# 11   구리시     7.7    14.3    16.1    19.4    20.7   21.9
# 12  남양주시     7.3    13.4    15.7    21.6    19.1   22.9
# 13   오산시     4.7    18.0    21.5    22.3    17.0   16.4
# 14   시흥시     6.8    16.2    18.4    21.6    20.7   16.4
# 15   군포시     6.1    16.2    16.7    19.2    20.2   21.5
# ...

# %%
age_ggd['15~19세 수'] = round(ggd_si['2019'] * age_ggd['15-19세']*1/100)
age_ggd['20~29세 수'] = round(ggd_si['2019'] * age_ggd['20-29세']*1/100)
age_count = age_ggd[['시군명','15~19세 수','20~29세 수']]
age_count = age_count.set_index('시군명')
age_count
# Out:
#       15~19세 수  20~29세 수
# 시군명
# 수원시    34420.0   88793.0
# 성남시    27632.0   60870.0
# 의정부시   12209.0   29759.0
# 안양시    17807.0   32721.0
# 부천시    21430.0   53405.0
# 광명시     8694.0   18270.0
# 평택시    17630.0   32547.0
# 동두천시    2408.0    5848.0
# 안산시    19691.0   50474.0
# 고양시    36458.0   61632.0
# 과천시     1653.0    3242.0
# 구리시     6150.0   11421.0
# 남양주시   20196.0   37072.0
# 오산시     4475.0   17138.0
# 시흥시    13243.0   31550.0
# 군포시     6710.0   17821.0
# 의왕시     4679.0    9171.0
# 하남시     7411.0   14127.0
# 용인시    32550.0   57370.0
# 파주시    14375.0   25684.0
# 이천시     7411.0   13619.0
# 안성시     5712.0   10445.0
# 김포시    13271.0   19906.0
# 화성시    23929.0   45892.0
# 광주시    10354.0   20081.0
# 양주시     8372.0   10512.0
# 포천시     4828.0    8677.0
# 여주시     3121.0    5839.0
# 연천군     1687.0    2206.0
# 가평군     1785.0    2061.0
# 양평군     3514.0    4407.0

# %%
age_count['합'] = age_count['15~19세 수'] + age_count['20~29세 수']

# %%
age_under_29 = age_count.sort_values(by='합', ascending=False).head(5)
age_under_29
# Out:
#      15~19세 수  20~29세 수         합
# 시군명
# 수원시   34420.0   88793.0  123213.0
# 고양시   36458.0   61632.0   98090.0
# 용인시   32550.0   57370.0   89920.0
# 성남시   27632.0   60870.0   88502.0
# 부천시   21430.0   53405.0   74835.0

# %%
age_count.sort_values(by='15~19세 수', ascending=False).head(5)
# Out:
#      15~19세 수  20~29세 수         합
# 시군명
# 고양시   36458.0   61632.0   98090.0
# 수원시   34420.0   88793.0  123213.0
# 용인시   32550.0   57370.0   89920.0
# 성남시   27632.0   60870.0   88502.0
# 화성시   23929.0   45892.0   69821.0

# %% [markdown]
# ### 경기도 학교

# %%
#고양
gy = pd.read_csv('./미니1차/경기도고양학교.csv', encoding='euc-kr')
gy
# Out:
#     교육과정별(1)     2019     2020
# 0   교육과정별(1)  학교수 (개)  학교수 (개)
# 1        중학교       41       42
# 2       고등학교       36       36
# 3  전문대학 및 대학        1        1
# 4        대학교        3        3
# 5        대학원        9       10

# %%
gy = gy.drop(0, axis=0)
gy
# Out:
#     교육과정별(1) 2019 2020
# 1        중학교   41   42
# 2       고등학교   36   36
# 3  전문대학 및 대학    1    1
# 4        대학교    3    3
# 5        대학원    9   10

# %%
gy_2019 = gy[['교육과정별(1)','2019']]
gy_2019['2019'] = gy_2019['2019'].astype(int)
gy_2019
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14320\2586628851.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gy_2019['2019'] = gy_2019['2019'].astype(int)
#     교육과정별(1)  2019
# 1        중학교    41
# 2       고등학교    36
# 3  전문대학 및 대학     1
# 4        대학교     3
# 5        대학원     9

# %%
gy_2019 = gy_2019.set_index('교육과정별(1)')
gy_2019
# Out:
#            2019
# 교육과정별(1)
# 중학교          41
# 고등학교         36
# 전문대학 및 대학     1
# 대학교           3
# 대학원           9

# %%
gy_2019.loc['대학교'] = gy_2019.loc['전문대학 및 대학'] + gy_2019.loc['대학교']
gy_2019
# Out:
#            2019
# 교육과정별(1)
# 중학교          41
# 고등학교         36
# 전문대학 및 대학     1
# 대학교           4
# 대학원           9

# %%
gy_2019 = gy_2019.drop('전문대학 및 대학',axis=0)
gy_2019
# Out:
#           2019
# 교육과정별(1)
# 중학교         41
# 고등학교        36
# 대학교          4
# 대학원          9

# %% [markdown]
# #### 고양 학교 그래프

# %%
plt.rc("font", family = "Malgun Gothic", size=10)
plt.plot(gy_2019, 'bo-')
plt.title('경기도 고양시 중학교~대학원 수')
plt.ylim(0,60)
# Out:
# (0.0, 60.0)

# %%
# 수원
sw = pd.read_excel('./미니1차/경기도수원학교.xlsx')
sw
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    교육과정별(1)  행정구역(구)별(1)     2019     2020     2021
# 0  교육과정별(1)  행정구역(구)별(1)  학교수 (개)  학교수 (개)  학교수 (개)
# 1       중학교           합계     56.0     56.0     57.0
# 2      고등학교           합계     44.0     44.0     44.0
# 3      전문대학           합계      2.0      2.0      2.0
# 4     대학(교)           합계      4.0      4.0      3.0
# 5       대학원           합계      4.0      4.0     22.0

# %%
sw = sw.drop(0, axis=0)

# %%
sw = sw.drop('행정구역(구)별(1)', axis=1)
sw
# Out:
#   교육과정별(1)  2019  2020  2021
# 1      중학교  56.0  56.0  57.0
# 2     고등학교  44.0  44.0  44.0
# 3     전문대학   2.0   2.0   2.0
# 4    대학(교)   4.0   4.0   3.0
# 5      대학원   4.0   4.0  22.0

# %%
sw_2019 = sw[['교육과정별(1)','2019']]
sw_2019['2019'] = sw_2019['2019'].astype(int)
sw_2019
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14320\766065888.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sw_2019['2019'] = sw_2019['2019'].astype(int)
#   교육과정별(1)  2019
# 1      중학교    56
# 2     고등학교    44
# 3     전문대학     2
# 4    대학(교)     4
# 5      대학원     4

# %%
sw_2019 = sw_2019.set_index('교육과정별(1)')
sw_2019
# Out:
#           2019
# 교육과정별(1)
# 중학교         56
# 고등학교        44
# 전문대학         2
# 대학(교)        4
# 대학원          4

# %%
# 대학은 합치기
sw_2019.loc['대학교'] = sw_2019.loc['전문대학'] + sw_2019.loc['대학(교)']
sw_2019
# Out:
#           2019
# 교육과정별(1)
# 중학교         56
# 고등학교        44
# 전문대학         2
# 대학(교)        4
# 대학원          4
# 대학교          6

# %%
sw_2019 = sw_2019.drop('전문대학',axis=0)

# %%
sw_2019 = sw_2019.drop('대학(교)',axis=0)
sw_2019
# Out:
#           2019
# 교육과정별(1)
# 중학교         56
# 고등학교        44
# 대학원          4
# 대학교          6

# %%
# 인덱스 위치 바꾸기
sw_2019 = sw_2019.reindex(index=['중학교','고등학교','대학교','대학원'])
sw_2019
# Out:
#           2019
# 교육과정별(1)
# 중학교         56
# 고등학교        44
# 대학교          6
# 대학원          4

# %% [markdown]
# ####  수원 학교 그래프

# %%
plt.rc("font", family = "Malgun Gothic", size=10)
plt.plot(sw_2019, 'go-')
plt.title('경기도 수원시 중학교~대학원 수')
plt.ylim(0,60)
# Out:
# (0.0, 60.0)

# %%
# 용인
yi = pd.read_csv('./미니1차/경기도용인학교.csv', encoding='euc-kr')
yi = yi.drop(0, axis=0)
yi
# Out:
#    교육과정별(1) 2019 2020
# 1       중학교   45   45
# 2       중학교    5    5
# 3    일반고등학교   26   26
# 4    일반고등학교    2    2
# 5   특성화고등학교    1    1
# 6   특성화고등학교    1    1
# 7    자율고등학교    1    1
# 8      전문대학    1    1
# 9     대학(교)    8    9
# 10      대학원   46   34

# %%
yi[['2019','2020']] =yi[['2019','2020']].astype(int)
yi = yi.groupby(['교육과정별(1)']).sum()
yi_2019 = yi[['2019']]
yi_2019
# Out:
#           2019
# 교육과정별(1)
# 대학(교)        8
# 대학원         46
# 일반고등학교      28
# 자율고등학교       1
# 전문대학         1
# 중학교         50
# 특성화고등학교      2

# %%
yi_2019.loc['대학교'] = yi_2019.loc['전문대학'] + yi_2019.loc['대학(교)']
yi_2019.loc['고등학교'] = yi_2019.loc['일반고등학교'] + yi_2019.loc['자율고등학교'] + yi_2019.loc['특성화고등학교']
yi_2019
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14320\2682762631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yi_2019.loc['대학교'] = yi_2019.loc['전문대학'] + yi_2019.loc['대학(교)']
# C:\Users\admin\AppData\Local\Temp\ipykernel_14320\2682762631.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yi_2019.loc['고등학교'] = yi_2019.loc['일반고등학교'] + yi_2019.loc['자율고등학교'] + yi_2019.loc['특성화고등학교']
#           2019
# 교육과정별(1)
# 대학(교)        8
# 대학원         46
# 일반고등학교      28
# 자율고등학교       1
# 전문대학         1
# 중학교         50
# 특성화고등학교      2
# 대학교          9
# 고등학교        31

# %%
yi_2019 = yi_2019.drop(['대학(교)','일반고등학교','자율고등학교','전문대학','특성화고등학교'])

# %%
yi_2019
# Out:
#           2019
# 교육과정별(1)
# 대학원         46
# 중학교         50
# 대학교          9
# 고등학교        31

# %%
yi_2019 = yi_2019.reindex(index=['중학교','고등학교','대학교','대학원'])
yi_2019
# Out:
#           2019
# 교육과정별(1)
# 중학교         50
# 고등학교        31
# 대학교          9
# 대학원         46

# %% [markdown]
# #### 용인 학교 그래프

# %%
# yi_2019 = yi_2019.set_index('교육과정별(1)')
plt.rc("font", family = "Malgun Gothic", size=10)
plt.figure(figsize=(8,5))
plt.plot(yi_2019, 'ro-')
plt.title('경기도 용인시 중학교~대학원 수')
plt.ylim(0,60)
# Out:
# (0.0, 60.0)

# %%
#성남
sn = pd.read_csv('./미니1차/경기도성남학교.csv', encoding='euc-kr')
sn = sn.drop(0, axis=0)
sn
# Out:
#      학교현황별(1) 학교현황별(2) 2019 2020
# 1         중학교      국공립   39   39
# 2         중학교       사립    8    6
# 3      일반고등학교      국공립   16   16
# 4      일반고등학교       사립   11   11
# 5    특수목적고등학교      국공립    1    1
# 6    특수목적고등학교       사립    1    1
# 7     특성화고등학교      국공립    4    4
# 8     특성화고등학교       사립    3    3
# 9   전문대학 및 대학       소계    3    3
# 10        대학교       소계    2    2
# 11        대학원       소계    8    8

# %%
sn[['2019','2020']] = sn[['2019','2020']].astype(int)
sn = sn.groupby(['학교현황별(1)']).sum()
sn
# Out:
#            2019  2020
# 학교현황별(1)
# 대학교           2     2
# 대학원           8     8
# 일반고등학교       27    27
# 전문대학 및 대학     3     3
# 중학교          47    45
# 특성화고등학교       7     7
# 특수목적고등학교      2     2

# %%
sn_2019 = sn[['2019']]
sn_2019
# Out:
#            2019
# 학교현황별(1)
# 대학교           2
# 대학원           8
# 일반고등학교       27
# 전문대학 및 대학     3
# 중학교          47
# 특성화고등학교       7
# 특수목적고등학교      2

# %%
sn_2019.loc['대학교'] = sn_2019.loc['전문대학 및 대학'] + sn_2019.loc['대학교']
sn_2019.loc['고등학교'] = sn_2019.loc['일반고등학교'] + sn_2019.loc['특성화고등학교']+ sn_2019.loc['특수목적고등학교']
sn_2019
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14320\3939544040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sn_2019.loc['대학교'] = sn_2019.loc['전문대학 및 대학'] + sn_2019.loc['대학교']
# C:\Users\admin\AppData\Local\Temp\ipykernel_14320\3939544040.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sn_2019.loc['고등학교'] = sn_2019.loc['일반고등학교'] + sn_2019.loc['특성화고등학교']+ sn_2019.loc['특수목적고등학교']
#            2019
# 학교현황별(1)
# 대학교           5
# 대학원           8
# 일반고등학교       27
# 전문대학 및 대학     3
# 중학교          47
# 특성화고등학교       7
# 특수목적고등학교      2
# 고등학교         36

# %%
sn_2019= sn_2019.drop(['전문대학 및 대학','일반고등학교','특수목적고등학교','특성화고등학교'])
sn_2019
# Out:
#           2019
# 학교현황별(1)
# 대학교          5
# 대학원          8
# 중학교         47
# 고등학교        36

# %%
sn_2019 = sn_2019.reindex(index=['중학교','고등학교','대학교','대학원'])
sn_2019
# Out:
#           2019
# 학교현황별(1)
# 중학교         47
# 고등학교        36
# 대학교          5
# 대학원          8

# %% [markdown]
# #### 성남 학교 그래프

# %%
plt.rc("font", family = "Malgun Gothic", size=10)
plt.figure(figsize=(9,5))
plt.plot(sn_2019, 'yo-')
plt.title('경기도 성남시 중학교~대학원 수')
plt.ylim(0,60)
# Out:
# (0.0, 60.0)

# %%
# 화성
hs = pd.read_csv('./미니1차/경기도화성학교.csv', encoding='euc-kr')
hs = hs.drop(0, axis=0)
hs
# Out:
#       학교별(1) 2019 2020
# 1        중학교   31   33
# 2        중학교    9    9
# 3     일반고등학교   18   20
# 4     일반고등학교    4    4
# 5   특수목적고등학교    1    1
# 6   특수목적고등학교    -    2
# 7    특성화고등학교    1    1
# 8    특성화고등학교    2    2
# 9     자율고등학교    -    -
# 10    자율고등학교    -    -
# 11      전문대학    2    2
# 12     대학(교)    4    4
# 13       대학원   20   19

# %%
hs.loc[6,'2019']=0
hs.loc[9,['2019','2020']]=0
hs.loc[10,['2019','2020']]=0

# %%
hs[['2019','2020']] = hs[['2019','2020']].astype(int)
hs = hs.groupby(['학교별(1)']).sum()
hs
# Out:
#           2019  2020
# 학교별(1)
# 대학(교)        4     4
# 대학원         20    19
# 일반고등학교      22    24
# 자율고등학교       0     0
# 전문대학         2     2
# 중학교         40    42
# 특성화고등학교      3     3
# 특수목적고등학교     1     3

# %%
hs_2019 = hs[['2019']]
hs_2019
# Out:
#           2019
# 학교별(1)
# 대학(교)        4
# 대학원         20
# 일반고등학교      22
# 자율고등학교       0
# 전문대학         2
# 중학교         40
# 특성화고등학교      3
# 특수목적고등학교     1

# %%
hs_2019.loc['대학교'] = hs_2019.loc['전문대학'] + hs_2019.loc['대학(교)']
hs_2019.loc['고등학교'] = hs_2019.loc['일반고등학교'] + hs_2019.loc['특성화고등학교']+ hs_2019.loc['특수목적고등학교']+hs_2019.loc['자율고등학교']
hs_2019
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14320\529415157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs_2019.loc['대학교'] = hs_2019.loc['전문대학'] + hs_2019.loc['대학(교)']
# C:\Users\admin\AppData\Local\Temp\ipykernel_14320\529415157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hs_2019.loc['고등학교'] = hs_2019.loc['일반고등학교'] + hs_2019.loc['특성화고등학교']+ hs_2019.loc['특수목적고등학교']+hs_2019.loc['자율고등학교']
#           2019
# 학교별(1)
# 대학(교)        4
# 대학원         20
# 일반고등학교      22
# 자율고등학교       0
# 전문대학         2
# 중학교         40
# 특성화고등학교      3
# 특수목적고등학교     1
# 대학교          6
# 고등학교        26

# %%
hs_2019= hs_2019.drop(['전문대학','일반고등학교','특수목적고등학교','특성화고등학교','대학(교)','자율고등학교'])
hs_2019 = hs_2019.reindex(index=['중학교','고등학교','대학교','대학원'])
hs_2019
# Out:
#         2019
# 학교별(1)
# 중학교       40
# 고등학교      26
# 대학교        6
# 대학원       20

# %% [markdown]
# #### 화성 학교 그래프

# %%
plt.rc("font", family = "Malgun Gothic", size=10)
plt.figure(figsize=(10,5))
plt.plot(hs_2019, 'mo-')
plt.title('경기도 화성시 중학교~대학원 수')
plt.ylim(0,60)
# Out:
# (0.0, 60.0)

# %%
#부천
bc = pd.read_csv('./미니1차/경기도부천학교.csv', encoding='euc-kr')
bc
# Out:
#    교육과정별(1)     2019     2020
# 0  교육과정별(1)  학교수 (개)  학교수 (개)
# 1       중학교       32       32
# 2      고등학교       28       28
# 3      전문대학        2        2
# 4       대학교        2        2
# 5       대학원        9        9

# %%
bc = bc.drop(0, axis=0)
bc = bc.set_index('교육과정별(1)')

# %%
bc_2019 = bc[['2019']]
bc_2019 = bc_2019.astype(int)
bc_2019
# Out:
#           2019
# 교육과정별(1)
# 중학교         32
# 고등학교        28
# 전문대학         2
# 대학교          2
# 대학원          9

# %%
bc_2019.loc['대학교'] = bc_2019.loc['전문대학'] + bc_2019.loc['대학교']
bc_2019
# Out:
#           2019
# 교육과정별(1)
# 중학교         32
# 고등학교        28
# 전문대학         2
# 대학교          4
# 대학원          9

# %%
bc_2019= bc_2019.drop(['전문대학'])
bc_2019
# Out:
#           2019
# 교육과정별(1)
# 중학교         32
# 고등학교        28
# 대학교          4
# 대학원          9

# %% [markdown]
# #### 부천 학교 그래프

# %%
plt.rc("font", family = "Malgun Gothic", size=10)
plt.figure(figsize=(10,5))
plt.plot(bc_2019, 'ko-')
plt.title('경기도 부천시 중학교~대학원 수')
plt.ylim(0,60)
# Out:
# (0.0, 60.0)

# %% [markdown]
# ### 경기도 총 학교 수

# %%
ggd_school = pd.read_csv('./미니1차/경기도총학교수.csv', encoding='euc-kr')

# %%
ggd_school = ggd_school.drop(0, axis=0)
ggd_school = ggd_school.set_index('교육과정별(1)')
ggd_school
# Out:
#           2019 2020
# 교육과정별(1)
# 중학교        630  638
# 고등학교       475  480
# 전문대학 및 대학   35   35
# 교육대학         1    1
# 대학교         37   37
# 대학원        180  179

# %%
ggd_school = ggd_school.astype(int)
ggd_school = ggd_school.drop('교육대학', axis=0)
ggd_school
# Out:
#            2019  2020
# 교육과정별(1)
# 중학교         630   638
# 고등학교        475   480
# 전문대학 및 대학    35    35
# 대학교          37    37
# 대학원         180   179

# %%
ggd_school.loc['대학교'] = ggd_school.loc['전문대학 및 대학'] + ggd_school.loc['대학교']
ggd_school
# Out:
#            2019  2020
# 교육과정별(1)
# 중학교         630   638
# 고등학교        475   480
# 전문대학 및 대학    35    35
# 대학교          72    72
# 대학원         180   179

# %%
ggd_school_2019= ggd_school.drop(['전문대학 및 대학'])
ggd_school_2019
# Out:
#           2019  2020
# 교육과정별(1)
# 중학교        630   638
# 고등학교       475   480
# 대학교         72    72
# 대학원        180   179

# %% [markdown]
# #### 부천 학교 그래프

# %%
plt.figure(figsize=(20,5))
fig, ax1 = plt.subplots()
ax1.bar(ggd_school_2019.index, ggd_school_2019['2019'],color='violet', label='Demand', alpha=0.7, width=0.7)
plt.ylim(0,650)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.title('경기도 학교 / 경기도 고양 학교 수', fontsize= 10)

ax2 = ax1.twinx()
ax2.plot(gy_2019.index, gy_2019['2019'],'-s', color='red', markersize=5, linewidth=3, alpha=0.7)
plt.ylim(0,65)
# Out:
# (0.0, 65.0)

# %% [markdown]
# ### 인구 연령대

# %%
ggd_si_index = ggd_si.set_index('행정구역(시군구)별')
ggd_si_index = ggd_si_index.loc[['수원시','고양시','용인시','성남시','부천시']]
ggd_si_index
# Out:
#               2019
# 행정구역(시군구)별
# 수원시         498836
# 고양시         434028
# 용인시         406880
# 성남시         400460
# 부천시         340160

# %%
age_total = age_count[['합']]
age_total = age_total.loc[['수원시','고양시','용인시','성남시','부천시']]
age_total
# Out:
#             합
# 시군명
# 수원시  123213.0
# 고양시   98090.0
# 용인시   89920.0
# 성남시   88502.0
# 부천시   74835.0

# %%
plt.figure(figsize=(50,5))
fig, ax1 = plt.subplots()
ax1.bar(ggd_si_index.index, ggd_si_index['2019'],color='violet', label='Demand', alpha=0.7, width=0.7)

plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.title('-', fontsize= 10)

ax2 = ax1.twinx()
ax2.plot(age_total.index, age_total['합'],'-s', color='red', markersize=5, linewidth=3, alpha=0.7)
plt.ylim()

# %%
ingu_age = pd.concat([ggd_si_index,age_total['합']], axis=1)
ingu_age
# Out:
#        2019         합
# 수원시  498836  123213.0
# 고양시  434028   98090.0
# 용인시  406880   89920.0
# 성남시  400460   88502.0
# 부천시  340160   74835.0

# %%
sns.set_palette('pastel')
plt.figure(figsize=(70,15))
ingu_age.plot(kind = 'bar')
plt.title('경기도 총 인구수 대 15~29세 인구수', fontsize=15)
plt.legend(fontsize = 10)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
# Out:
# (array([     0., 100000., 200000., 300000., 400000., 500000., 600000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### 인구 수 학교 수

# %%
# 경기도 전체 학교
ggd_school_2019
# Out:
#           2019  2020
# 교육과정별(1)
# 중학교        630   638
# 고등학교       475   480
# 대학교         72    72
# 대학원        180   179

# %%
# 수원
sw_2019
sum = pd.DataFrame(sw_2019.sum(axis=0))
sum = sum.rename(columns={0:'수원시'})
sw_sum = sum.T

# %%
#고양
gy_2019
sum = pd.DataFrame(gy_2019.sum(axis=0))
sum = sum.rename(columns={0:'고양시'})
gy_sum = sum.T

# %%
#용인
yi_2019
sum = pd.DataFrame(yi_2019.sum(axis=0))
sum = sum.rename(columns={0:'용인시'})
yi_sum = sum.T

# %%
# 성남
sn_2019
sum = pd.DataFrame(sn_2019.sum(axis=0))
sum = sum.rename(columns={0:'성남시'})
sn_sum = sum.T

# %%
# 부천
bc_2019
sum = pd.DataFrame(bc_2019.sum(axis=0))
sum = sum.rename(columns={0:'부천시'})
bc_sum = sum.T

# %%
bc_sum
# Out:
#      2019
# 부천시    73

# %%
school = pd.concat([sw_sum,gy_sum,yi_sum,sn_sum,bc_sum], axis=0)
school = school.rename(columns={'2019':'학교수'})
school[['학교수']]
# Out:
#      학교수
# 수원시  110
# 고양시   90
# 용인시  136
# 성남시   96
# 부천시   73

# %%
ingu_age
# Out:
#        2019         합
# 수원시  498836  123213.0
# 고양시  434028   98090.0
# 용인시  406880   89920.0
# 성남시  400460   88502.0
# 부천시  340160   74835.0

# %%
ingu_age_school = pd.concat([ingu_age,school[['학교수']]],axis=1)
ingu_age_school
# Out:
#        2019         합  학교수
# 수원시  498836  123213.0  110
# 고양시  434028   98090.0   90
# 용인시  406880   89920.0  136
# 성남시  400460   88502.0   96
# 부천시  340160   74835.0   73

# %%
ingu_age_school.plot()
# Out:
# <AxesSubplot:>
